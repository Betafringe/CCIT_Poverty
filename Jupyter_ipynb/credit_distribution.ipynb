# %%
import numpy as np
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('credit_user_info.csv')
df.describe()
# Out:
#                  id        score    character  appointment      history  \
# count  3.000000e+03  3000.000000  3000.000000  3000.000000  3000.000000
# mean   9.874791e+05   510.209333     0.467091     0.606183     0.475233
# std    5.337223e+05    58.750246     0.121064     0.090787     0.105009
# min    1.837200e+04   395.000000     0.300000     0.510000     0.400000
# 25%    5.574565e+05   465.000000     0.390000     0.510000     0.400000
# 50%    9.981615e+05   503.000000     0.450000     0.630000     0.400000
# 75%    1.431493e+06   552.000000     0.530000     0.650000     0.600000
# max    1.910155e+06   691.000000     0.910000     0.840000     0.700000
#
#         stickiness    relations  analyze
# count  3000.000000  3000.000000      0.0
# mean      0.659360     0.632333      NaN
# std       0.116042     0.068245      NaN
# min       0.570000     0.520000      NaN
# 25%       0.570000     0.580000      NaN
# 50%       0.570000     0.620000      NaN
# ...

# %% [markdown]
# ### 良好 	0.500000	0.650000	0.600000	0.800000	0.700000

# %%
df.hist('score', bins = 50)
plt.show()

# %%
df.corr()
# Out:
#                    id     score  character  appointment   history  stickiness  \
# id           1.000000  0.018829  -0.025982    -0.042461 -0.090810    0.218148
# score        0.018829  1.000000   0.676559     0.811276  0.753405    0.481138
# character   -0.025982  0.676559   1.000000     0.530712  0.322860    0.069422
# appointment -0.042461  0.811276   0.530712     1.000000  0.772915    0.138351
# history     -0.090810  0.753405   0.322860     0.772915  1.000000    0.217147
# stickiness   0.218148  0.481138   0.069422     0.138351  0.217147    1.000000
# relations    0.000487  0.553643   0.342409     0.406980  0.297336    0.115035
# analyze           NaN       NaN        NaN          NaN       NaN         NaN
#
#              relations  analyze
# id            0.000487      NaN
# score         0.553643      NaN
# character     0.342409      NaN
# appointment   0.406980      NaN
# history       0.297336      NaN
# stickiness    0.115035      NaN
# relations     1.000000      NaN
# ...
