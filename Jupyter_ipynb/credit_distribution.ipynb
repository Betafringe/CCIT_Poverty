# %%
import numpy as np
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt

# %%
path = '/Users/betafringe/Devproject/python/ProjectPoverty/__CreditAnalyse/data/csv/all_credit_user_info.csv'
df = pd.read_csv(path)
df.describe()
# Out:
#                  id         score     character   appointment       history  \
# count  1.817000e+06  1.817000e+06  1.817000e+06  1.817000e+06  1.817000e+06
# mean   1.040767e+06  5.416870e+02  5.007691e-01  6.072784e-01  4.777271e-01
# std    5.581871e+05  5.426888e+01  1.219856e-01  9.364669e-02  1.120999e-01
# min    5.931000e+03  4.400000e+02  3.200000e-01  5.100000e-01  4.000000e-01
# 25%    5.903878e+05  4.990000e+02  4.400000e-01  5.100000e-01  4.000000e-01
# 50%    1.055574e+06  5.350000e+02  4.800000e-01  6.300000e-01  4.000000e-01
# 75%    1.509826e+06  5.780000e+02  5.600000e-01  6.500000e-01  6.000000e-01
# max    1.991862e+06  7.520000e+02  9.872000e-01  8.400000e-01  7.000000e-01
#
#          stickiness     relations  analyze
# count  1.817000e+06  1.817000e+06      0.0
# mean   8.100271e-01  6.314068e-01      NaN
# std    2.128642e-03  6.695872e-02      NaN
# min    5.700000e-01  5.000000e-01      NaN
# 25%    8.100000e-01  5.800000e-01      NaN
# 50%    8.100000e-01  6.200000e-01      NaN
# 75%    8.100000e-01  7.000000e-01      NaN
# max    8.410000e-01  8.000000e-01      NaN

# %% [markdown]
# ### 良好 	0.500000	0.650000	0.600000	0.800000	0.700000

# %%
df.hist('score', bins = 50)
plt.show()

# %%
df.corr()
# Out:
#                    id     score  character  appointment   history  stickiness  \
# id           1.000000  0.027639   0.016334     0.038970 -0.004407   -0.033178
# score        0.027639  1.000000   0.744144     0.861278  0.780069    0.007447
# character    0.016334  0.744144   1.000000     0.523516  0.336051   -0.002624
# appointment  0.038970  0.861278   0.523516     1.000000  0.790648    0.007953
# history     -0.004407  0.780069   0.336051     0.790648  1.000000    0.007331
# stickiness  -0.033178  0.007447  -0.002624     0.007953  0.007331    1.000000
# relations    0.051385  0.616865   0.436095     0.431903  0.323705    0.015517
# analyze           NaN       NaN        NaN          NaN       NaN         NaN
#
#              relations  analyze
# id            0.051385      NaN
# score         0.616865      NaN
# character     0.436095      NaN
# appointment   0.431903      NaN
# history       0.323705      NaN
# stickiness    0.015517      NaN
# relations     1.000000      NaN
# analyze            NaN      NaN

# %%
df_all = pd.read_csv(path)
