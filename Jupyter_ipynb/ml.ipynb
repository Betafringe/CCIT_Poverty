# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn import preprocessing

# %%
df_ = pd.read_csv('preprocessing_data.csv')
credit = pd.read_csv('credit_user_info_view.csv')
df_.head()
# Out:
#    Unnamed: 0       id  per_num  year  ID_card level  breed_year  equip_breed  \
# 0           1  1313985        3  2017       37     1         NaN          NaN
# 1           2   127339        1  2014       69     2         NaN          NaN
# 2           3   571526        2  2016       49     3         NaN          NaN
# 3           4   182756        3  2016       79     1         NaN          NaN
# 4           5  1502275        3  2014       11     1         NaN          NaN
#
#    land_year  land_size  ...         town_id    village_id    helper_unit  \
# 0        NaN        NaN  ...    510823212000  510823212205            NaN
# 1        NaN        NaN  ...    510821100000  510821100217  旺苍县东河镇农业推广服务站
# 2        NaN        NaN  ...    511324100000  511324100205            NaN
# 3        NaN        NaN  ...    513429218000  513429218208            NaN
# 4        NaN        NaN  ...    511724205000  511724205200            NaN
#
# ...

# %%
credit.head()
# Out:
#         id name  score  character  appointment  history  stickiness  \
# 0   250485  abc    692     0.8392         0.72      0.7        0.81
# 1   262525  abc    692     0.9160         0.72      0.7        0.81
# 2  1592120  abc    679     0.9000         0.72      0.7        0.81
# 3  1762380  abc    677     0.9000         0.72      0.7        0.81
# 4   835639  abc    673     0.7976         0.72      0.7        0.81
#
#    relations  analyze
# 0       0.76      NaN
# 1       0.76      NaN
# 2       0.64      NaN
# 3       0.64      NaN
# 4       0.64      NaN
